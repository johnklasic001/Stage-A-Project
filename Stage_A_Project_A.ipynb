# %%
import pandas as pd                        #Importing libries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sms

# %%
df = pd.read_csv('/content/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')  #uploading csv file

# %%
df.head()                                             #checking headings
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.info()                                       #ascertaining dataframe information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.dropna().shape
# Out:
# (57784, 12)

# %%
df2 = df.drop(['Y2014'], axis = 1)

# %%
df2 = df.drop(['Y2015'], axis = 1)

# %%
df2 = df.drop(['Y2016'], axis = 1)

# %%
df2 = df.drop(['Y2017'], axis = 1)

# %%
df2 = df.drop(['Y2018'], axis = 1)

# %%
df2.dropna(inplace = True)

# %%
df2.isna().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# dtype: int64

# %%
numerical_df = df2.select_dtypes(include = [int, float])

# %%
numerical_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  58026.000000  58026.000000  58026.000000   58026.000000   58026.000000
# mean     134.475184   2690.354341   3751.190983     137.262827     138.417253
# std       72.680554    146.602104   2217.407780    1585.368961    1622.073095
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2563.000000    674.000000       0.000000       0.000000
# 50%      136.000000   2633.000000   5142.000000       0.140000       0.130000
# 75%      197.000000   2781.000000   5301.000000       9.000000       9.000000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017
# count   58026.000000   58026.000000
# mean      139.797792     144.329585
# std      1659.286308    1691.922628
# min     -3225.000000   -1582.000000
# 25%         0.000000       0.000000
# 50%         0.130000       0.150000
# ...

# %%
categorical = df2.select_dtypes(exclude = [int, float])

# %%
categorical.info()                   #dataframe now have only object data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58026 entries, 0 to 60942
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Area     58026 non-null  object
#  1   Item     58026 non-null  object
#  2   Element  58026 non-null  object
#  3   Unit     58026 non-null  object
# dtypes: object(4)
# memory usage: 2.2+ MB

# %%
categorical.describe()
# Out:
#          Area                     Item                   Element         Unit
# count   58026                    58026                     58026        58026
# unique     49                      119                        18            5
# top     Kenya  Milk - Excluding Butter  Domestic supply quantity  1000 tonnes
# freq     1521                     1234                      5219        38367

# %%
numerical_df.corr()                       #checking numerical correlation
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005257      0.002921  0.006106  0.005284
# Item Code     -0.005257   1.000000     -0.017702  0.021144  0.020269
# Element Code   0.002921  -0.017702      1.000000  0.025986  0.025365
# Y2014          0.006106   0.021144      0.025986  1.000000  0.994647
# Y2015          0.005284   0.020269      0.025365  0.994647  1.000000
# Y2016          0.005262   0.019425      0.024818  0.996081  0.995739
# Y2017          0.004996   0.020853      0.025665  0.995230  0.988047
#
#                  Y2016     Y2017
# Area Code     0.005262  0.004996
# Item Code     0.019425  0.020853
# Element Code  0.024818  0.025665
# Y2014         0.996081  0.995230
# Y2015         0.995739  0.988047
# Y2016         1.000000  0.992784
# Y2017         0.992784  1.000000

# %%
sms.countplot(categorical, x = 'Unit')        #using seaborn for presentation
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '1000 persons'),
#   Text(1, 0, '1000 tonnes'),
#   Text(2, 0, 'kcal/capita/day'),
#   Text(3, 0, 'g/capita/day'),
#   Text(4, 0, 'kg')])

# %%
categorical['Unit'].value_counts().plot(kind = 'pie', autopct='%1.1f%%')     #pie chart presentation
# Out:
# <Axes: ylabel='Unit'>
